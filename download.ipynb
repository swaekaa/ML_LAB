# %%
import kagglehub

# Download latest version

path = kagglehub.dataset_download("aldinwhyudii/student-depression-and-lifestyle-100k-data")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.4.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/aldinwhyudii/student-depression-and-lifestyle-100k-data?dataset_version_number=1...
# 100%|██████████| 1.25M/1.25M [00:02<00:00, 456kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Ekaansh\.cache\kagglehub\datasets\aldinwhyudii\student-depression-and-lifestyle-100k-data\versions\1
